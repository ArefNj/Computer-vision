# %% [markdown]
# <a href="https://colab.research.google.com/github/ArefNj/Computer-vision/blob/main/Yolov5_Object_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python -m pip install --upgrade pip

# !pip install tensorflow

# !pip install tensorboard

# %%
# !pip install torch

# %%
import torch
from IPython.display import Image

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16936, done.
# remote: Counting objects: 100% (131/131), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 16936 (delta 67), reused 92 (delta 51), pack-reused 16805 (from 1)
# Receiving objects: 100% (16936/16936), 15.69 MiB | 23.14 MiB/s, done.
# Resolving deltas: 100% (11596/11596), done.
# /content/yolov5
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.3/687.3 kB 14.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 50.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 872.3/872.3 kB 25.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 979.1/979.1 kB 28.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 58.8 MB/s eta 0:00:00

# %% [markdown]
# # Use pre-trained model

# %% [markdown]
# Use Yolov5s

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source '/content/hq720.jpg'
# Out:
# detect: weights=['yolov5s.pt'], source=/content/hq720.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-363-gf44db010 Python-3.10.12 torch-2.4.0+cu121 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# image 1/1 /content/hq720.jpg: 384x640 12 persons, 1 handbag, 316.1ms
# Speed: 4.0ms pre-process, 316.1ms inference, 3.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp7

# %%
Image('/content/hq720.jpg')

# %%
Image('/content/yolov5/runs/detect/exp7/hq720.jpg')

# %% [markdown]
# Cheange Threshold

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.7 --source '/content/hq720.jpg'
# Out:
# detect: weights=['yolov5s.pt'], source=/content/hq720.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.7, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-363-gf44db010 Python-3.10.12 torch-2.4.0+cu121 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# image 1/1 /content/hq720.jpg: 384x640 6 persons, 294.4ms
# Speed: 2.2ms pre-process, 294.4ms inference, 3.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp8

# %%
Image('/content/yolov5/runs/detect/exp8/hq720.jpg')
